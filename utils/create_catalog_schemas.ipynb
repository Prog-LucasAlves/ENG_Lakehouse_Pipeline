# %%
# %sql
CREATE CATALOG IF NOT EXISTS lakehouse
COMMENT "Catálogo principal do projeto";

CREATE SCHEMA IF NOT EXISTS lakehouse.raw
COMMENT "Camada RAW -  dados brutos";

CREATE SCHEMA IF NOT EXISTS lakehouse.bronze
COMMENT "Camada BRONZE - dados padronizados, com metadados e controlr de ingestão";

CREATE SCHEMA IF NOT EXISTS lakehouse.silver
COMMENT "Camada SILVER - dados padronizados, com regras de negócio aplicadas";

CREATE SCHEMA IF NOT EXISTS lakehouse.gold
COMMENT "Camada GOLD - dados analíticos, e méricas finais para BI e IA";

SHOW SCHEMAS FROM lakehouse;

# %%
# %sql
DROP SCHEMA lakehouse.postgres_render_public CASCADE
